# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %% [markdown]
# # Questions for Netflix Data Analysis
#
# 1. **What is the distribution of movie genres released in the 1990s?**
#    - Analyze how many movies belong to each genre and identify the most popular genres during this decade.
#
# 2. **What was the trend in the number of movies released each year in the 1990s?**
#    - Create a time series analysis to visualize the number of movies released per year and identify any notable trends or spikes.
#
# 3. **What is the average duration of movies released in the 1990s?**
#    - Calculate the mean and median durations of movies from this decade and explore if certain genres tend to have longer or shorter runtimes.
#
# 4. **How do user ratings for movies released in the 1990s compare to those from other decades?**
#    - Investigate if movies from the 1990s received higher or lower ratings compared to movies from other decades.
#
# 5. **Which 1990s movies have the highest and lowest ratings?**
#    - Identify the top-rated and lowest-rated movies from the 1990s to understand what stood out during that era.
#
# 6. **What are the common themes or keywords found in movie titles from the 1990s?**
#    - Perform a text analysis on movie titles to find common themes, keywords, or patterns in the naming of movies.
#
# 7. **How does the representation of various demographics (e.g., gender, ethnicity) in movies from the 1990s compare to today?**
#    - Examine the cast and crew data (if available) to analyze the representation of different demographics in 1990s movies.
#
# 8. **What was the impact of critical acclaim on the popularity of 1990s movies?**
#    - Investigate if there is a correlation between critical ratings (like awards) and the viewership or popularity of movies released in the 1990s.
#
# 9. **How did the release of blockbuster movies in the 1990s influence the overall movie landscape on Netflix?**
#    - Analyze the release dates and success of blockbuster films to determine if they impacted the types of movies released in subsequent years.
#
# 10. **What recommendations can be made for producing nostalgic films based on audience preferences in the 1990s?**
#     - Based on the analysis of ratings, genres, and trends, propose insights and recommendations for creating films that resonate with the nostalgic sentiments of audiences today.

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Start coding here! Use as many cells as you like

# %%
movies_in_1990 = netflix_df[(netflix_df['release_year'] >= 1990) & (netflix_df['release_year'] < 2000)]

duration = movies_in_1990['duration'].mode().iloc[0]

short_action_movies = movies_in_1990[(movies_in_1990['duration']<90) & (movies_in_1990['genre']=='Action') ]
short_movie_count = short_action_movies.shape[0]
short_movie_count
# Out:
# 7
